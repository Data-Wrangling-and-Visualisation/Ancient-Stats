# %%
from requests import get

# %%
account_id = 318334842
#account_id = 1021508551

# %%
json = get(f'https://api.opendota.com/api/players/{account_id}/recentMatches').json()
# Out:
# 1lyaneX
# https://steamcommunity.com/id/IlyaneX/

# %%
len(json)
# Out:
# [{'id': 8203728425,
#   'win': True,
#   'duration': 2021,
#   'game_mode': 22,
#   'hero_id': 44,
#   'time': 1741331244,
#   'kills': 14,
#   'deaths': 6,
#   'assists': 12},
#  {'id': 8203012928,
#   'win': True,
#   'duration': 2944,
#   'game_mode': 22,
#   'hero_id': 48,
#   'time': 1741276006,
#   'kills': 5,
#   'deaths': 12,
#   'assists': 8},
#  {'id': 8202963260,
#   'win': False,
#   'duration': 1693,
#   'game_mode': 22,
#   'hero_id': 1,
#   'time': 1741273937,
#   'kills': 0,
#   'deaths': 10,
#   'assists': 5},
#  {'id': 8202038694,
#   'win': True,
#   'duration': 2242,
#   'game_mode': 22,
#   'hero_id': 1,
#   'time': 1741203681,
#   'kills': 12,
#   'deaths': 8,
#   'assists': 16},
#  {'id': 8201976986,
#   'win': False,
#   'duration': 2514,
#   'game_mode': 22,
#   'hero_id': 89,
#   'time': 1741200531,
#   'kills': 11,
#   'deaths': 6,
#   'assists': 9},
#  {'id': 8201825880,
#   'win': True,
#   'duration': 1795,
#   'game_mode': 22,
#   'hero_id': 48,
# ...

# %%
json = get(f'https://api.opendota.com/api/players/{account_id}/matches').json()

# %%
json
# Out:
# [{'match_id': 8203728425,
#   'player_slot': 1,
#   'radiant_win': True,
#   'duration': 2021,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 44,
#   'start_time': 1741331244,
#   'version': None,
#   'kills': 14,
#   'deaths': 6,
#   'assists': 12,
#   'average_rank': 43,
#   'leaver_status': 0,
#   'party_size': None,
#   'hero_variant': 3},
#  {'match_id': 8203012928,
#   'player_slot': 4,
#   'radiant_win': True,
#   'duration': 2944,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 48,
#   'start_time': 1741276006,
#   'version': None,
#   'kills': 5,
#   'deaths': 12,
#   'assists': 8,
#   'average_rank': 43,
#   'leaver_status': 0,
#   'party_size': None,
#   'hero_variant': 3},
#  {'match_id': 8202963260,
#   'player_slot': 131,
#   'radiant_win': True,
#   'duration': 1693,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 1,
#   'start_time': 1741273937,
#   'version': None,
#   'kills': 0,
#   'deaths': 10,
#   'assists': 5,
# ...

# %%
len(json)
# Out:
# 1725

# %%
get('https://api.opendota.com/api/matches/8203728425').json()
# Out:
# {'players': [{'account_id': 1144821954,
#    'player_slot': 0,
#    'team_number': 0,
#    'team_slot': 0,
#    'hero_id': 17,
#    'hero_variant': 2,
#    'item_0': 63,
#    'item_1': 36,
#    'item_2': 41,
#    'item_3': 77,
#    'item_4': 1806,
#    'item_5': 273,
#    'backpack_0': 0,
#    'backpack_1': 38,
#    'backpack_2': 0,
#    'item_neutral': 356,
#    'item_neutral2': 1583,
#    'kills': 12,
#    'deaths': 2,
#    'assists': 20,
#    'leaver_status': 0,
#    'last_hits': 166,
#    'denies': 6,
#    'gold_per_min': 530,
#    'xp_per_min': 657,
#    'level': 20,
#    'net_worth': 17394,
#    'aghanims_scepter': 0,
#    'aghanims_shard': 1,
#    'moonshard': 0,
#    'hero_damage': 28075,
#    'tower_damage': 10418,
#    'hero_healing': 0,
#    'gold': 639,
#    'gold_spent': 17660,
#    'ability_upgrades_arr': [5098,
#     5100,
#     5098,
#     5099,
#     5098,
#     5101,
#     5098,
#     5100,
#     5100,
#     7132,
#     5100,
#     5101,
#     5099,
#     5099,
# ...
